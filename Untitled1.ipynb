# %%
import pandas as pd

# %%
df = pd.read_csv("movie_edited.csv")
df
# Out:
#      Unnamed: 0                           title  rating  year     month  \
# 0             0        Avatar: The Way of Water     7.8  2022  December
# 1             1  Guillermo del Toro's Pinocchio     7.6  2022  December
# 2             2                    Bullet Train     7.3  2022    August
# 3             3       The Banshees of Inisherin     7.8  2022  November
# 4             4                           M3gan     6.4  2022  December
# ..          ...                             ...     ...   ...       ...
# 369         369                            Jexi     6.0  2019   October
# 370         370         Fighting with My Family     7.1  2019  February
# 371         371          Zombieland: Double Tap     6.7  2019   October
# 372         372                        Vivarium     5.8  2019     March
# 373         373        The Peanut Butter Falcon     7.6  2019    August
#
#     certificate  runtime                           directors  \
# ...

# %%
rating_df = df.groupby(by=["title"]).rating.sum()
rating_df.sort_values(ascending=False)
rating_df_top = rating_df[(rating_df >=7.5)].sort_values(ascending=False)
rating_df_top
# Out:
# title
# Pinocchio                              11.3
# Drishyam 2                              8.6
# Parasite                                8.5
# Kantara                                 8.5
# Hamilton                                8.4
# Farha                                   8.4
# Top Gun: Maverick                       8.4
# Avengers: Endgame                       8.4
# Joker                                   8.4
# Spider-Man: No Way Home                 8.3
# The Father                              8.2
# 1917                                    8.2
# Demon Slayer the Movie: Mugen Train     8.2
# Portrait of a Lady on Fire              8.1
# Ford v Ferrari                          8.1
# Everything Everywhere All at Once       8.1
# Klaus                                   8.1
# Dune                                    8.0
# Zack Snyder's Justice League            8.0
# An Action Hero                          8.0
# Soul                                    8.0
# ...
